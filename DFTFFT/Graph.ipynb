# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A_a_DFT=np.loadtxt("A_a_DFT.dat")

# %%
#plt.xlim(0,512//8)
plt.plot(A_a_DFT)

# %%
A_a_DFT_INVERSE=np.loadtxt("A_a_DFT_INVERSE.dat")

# %%
plt.plot(A_a_DFT_INVERSE)

# %%
A_a_FFT=np.loadtxt("A_a_FFT.dat")

# %%
plt.plot(A_a_FFT[0:256])

# %%
A_a_FFT_INVERSE=np.loadtxt("A_a_FFT_INVERSE.dat")

# %%
plt.plot(A_a_FFT_INVERSE)

# %%
A_a=np.loadtxt("A_a_dumped.dat")

# %%
plt.plot(A_a[0:512])
